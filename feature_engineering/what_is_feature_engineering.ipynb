# %% [markdown]
# # What is Feature Engineering?
#
# * determine which features are the most important with mutual information
# * invent new features in several real-world problem domains
# * encode high-cardinality categoricals with a target encoding
# * create segmentation features with k-means clustering
# * decompose a dataset's variation into features with principal component analysis

# %% [markdown]
# ### The Goal
#
# The goal of feature engineering is to make the data you have better suited for the problem you are trying to solve.
#
# Can be applied to:
# * improve a model's predictive performance
# * reduce computational or data needs
# * improve interpretability of the results

# %% [markdown]
# ### A Guiding Principle
#
# Whatever relationships the model cannot learn (For example having a linear model try to predict data that is parabolic in nature) can be provided through a transformation of the data.
